# %%
import pandas as pd

# %%
next_data = pd.read_csv('next_dataset5.csv')

# %%
next_data
# Out:
#          Unnamed: 0       Id  Price  Year  Mileage            City State  \
# 0                 0        1  16472  2015    18681  Jefferson City    MO
# 1                 1        2  15749  2015    27592        Highland    IN
# 2                 2        3  16998  2015    13650           Boone    NC
# 3                 3        4  15777  2015    25195     New Orleans    LA
# 4                 4        5  16784  2015    22800       Las Vegas    NV
# ...             ...      ...    ...   ...      ...             ...   ...
# 1230690     1233037  1233038  79900  2017       25    East Hanover    NJ
# 1230691     1233038  1233039  80895  2017       10    Corte Madera    CA
# 1230692     1233039  1233040  68755  2018     2500       Englewood    NJ
# 1230693     1233040  1233041  72260  2017     3201       Englewood    NJ
# 1230694     1233041  1233042  60240  2017     8342     San Leandro    CA
#
#                        Vin   Make              Model
# ...

# %%
next_data['State'].nunique()
# Out:
# 51

# %%
next_data.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
next_data
# Out:
#               Id  Price  Year  Mileage            City State  \
# 0              1  16472  2015    18681  Jefferson City    MO
# 1              2  15749  2015    27592        Highland    IN
# 2              3  16998  2015    13650           Boone    NC
# 3              4  15777  2015    25195     New Orleans    LA
# 4              5  16784  2015    22800       Las Vegas    NV
# ...          ...    ...   ...      ...             ...   ...
# 1230690  1233038  79900  2017       25    East Hanover    NJ
# 1230691  1233039  80895  2017       10    Corte Madera    CA
# 1230692  1233040  68755  2018     2500       Englewood    NJ
# 1230693  1233041  72260  2017     3201       Englewood    NJ
# 1230694  1233042  60240  2017     8342     San Leandro    CA
#
#                        Vin   Make              Model
# 0        KL4CJBSBXFB267643  Buick  EncoreConvenience
# 1        KL4CJASB5FB245057  Buick          EncoreFWD
# 2        KL4CJCSB0FB264921  Buick      EncoreLeather
# ...

# %%
next_data['Model'] = next_data['Model'].replace(
    {'"Excursion137"""': 'Excursion137'})

# %%
next_data['Model'] = next_data['Model'].replace(
    {'"Expedition119"""': 'Expedition119'})

# %%
next_data['Model'] = next_data['Model'].replace(
    {'"1500**7"""': '1500'})

# %%
next_data['Model'] = next_data.Model.str.replace('"','')

# %%
next_data['Model'] = next_data.Model.str.replace('*','')

# %%
df5 = next_data[next_data['Mileage'] < 500000]
df5
# Out:
#               Id  Price  Year  Mileage            City State  \
# 0              1  16472  2015    18681  Jefferson City    MO
# 1              2  15749  2015    27592        Highland    IN
# 2              3  16998  2015    13650           Boone    NC
# 3              4  15777  2015    25195     New Orleans    LA
# 4              5  16784  2015    22800       Las Vegas    NV
# ...          ...    ...   ...      ...             ...   ...
# 1230690  1233038  79900  2017       25    East Hanover    NJ
# 1230691  1233039  80895  2017       10    Corte Madera    CA
# 1230692  1233040  68755  2018     2500       Englewood    NJ
# 1230693  1233041  72260  2017     3201       Englewood    NJ
# 1230694  1233042  60240  2017     8342     San Leandro    CA
#
#                        Vin   Make              Model
# 0        KL4CJBSBXFB267643  Buick  EncoreConvenience
# 1        KL4CJASB5FB245057  Buick          EncoreFWD
# 2        KL4CJCSB0FB264921  Buick      EncoreLeather
# ...

# %%
df5.to_csv('final_data.csv')
